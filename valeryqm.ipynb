# %% [markdown]
# <a href="https://colab.research.google.com/github/valeryquispe/valeryqm/blob/main/valeryqm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Regresion Lineal
#
# ---

# %% [markdown]
# Link del [archivo](https://drive.google.com/drive/folders/1vgl0rqWlOQYf970zxj6QTgXJ0mg8L-cv?usp=sharing)

# %%
import pandas as pd
dataset = pd.read_csv("/content/https://drive.google.com/drive/)
print(dataset.head())

x = dataset['Father'].values.reshape(-1,1)
y = dataset['Son'].values
# Out:
#     Father      Son
# 0  165.100  151.892
# 1  160.782  160.528
# 2  165.100  160.782
# 3  167.132  159.512
# 4  155.194  163.322

# %% [markdown]
# Ahora ajustemos la regresión lineal a nuestro modelo

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(x, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a33b7f993181> in <module>()
#       2
#       3 lin_reg = LinearRegression()
# ----> 4 lin_reg.fit(x, y)
#
# NameError: name 'x' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-d5df0069828e> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     254             ': timeout during initial read of root folder; for more info: '
#     255             'https://research.google.com/colaboratory/faq.html#drive-timeout')
# --> 256       raise ValueError('mount failed' + extra_reason)
#     257     elif case == 2:
#     258       # Not already authorized, so do the authorization dance.
#
# ValueError: mount failed

# %% [markdown]
# Podemos graficar nuestros datos y compararlos con las predicciones de nuestro modelo.

# %%
import matplotlib.pyplot as plt

plt.scatter(x, y, color = 'b', alpha = 0.3)
plt.plot(x, lin_reg.predict(x), color = 'red', linewidth=2)
plt.title('Estatura Padre vs Estatura Hijo')
plt.xlabel('Estatura Padre')
plt.ylabel('Estatura Hijo')
plt.show()

# %% [markdown]
# Vamos a predecir !

# %%
lin_reg.predict([[165]])
# Out:
# array([170.89868894])

# %% [markdown]
# Url : [Modelo de presentacion final](https://drive.google.com/drive/folders/1Oh3cuBxUxXQ1JURPD4L4R960kKaadg_d?usp=sharing)
